# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import  seaborn as sns
import plotly.express as px

# %%
plt.style.use('default')

# %% [markdown]
# # facet(row,col )  function is fig level not working with hisplot

# %% [markdown]
# # seaborn cate
# relational plot-bivariate(2 or more variable)
# 1 scatterplot
# 2 lineplot

# %%
data =pd.read_csv('Pune_House_Data.csv')
data
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price         site_location
# ...

# %%
data2 =pd.read_csv('House_prediction.csv')
data2
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
data3 =pd.read_csv('flipkart.csv')
data3
# Out:
#           flipkart_author  flipkart_isbn10  \
# 0          Sidney Sheldon       8172234902
# 1                               1862305277
# 2              Anil Lamba       9350294311
# 3       Bar-Zohar Michael       8184958455
# 4              Kamala Das       8172238975
# ...                   ...              ...
# 1377     Stilton Geronimo       9385887815
# 1378        J. K. Rowling       1408855712
# 1379         Arni Samhita       9380340036
# 1380        James Dashner       9351039684
# 1381              unknown       9386041901
#
#                                        flipkart_title flipkart_ratings count  \
# 0                                 TELL ME YOUR DREAMS                    902
# 1                      The Boy in the Striped Pyjamas                     83
# 2                         ROMANCING THE BALANCE SHEET                    352
# 3                                              Mossad                    560
# ...

# %%
data4 =pd.read_csv('test.csv')
data4
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
sns.scatterplot(data['area_type'],data['price'],data=data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area_type', ylabel='price'>

# %%
sns.swarmplot(data['area_type'],data['price'],data=data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(data['bath'],data['price'],data=data)

# %%
sns.catplot(x='area_type',y='price',data=data,kind='strip',jitter=False)

# %%
sns.catplot(data['area_type'],data['price'],data=data,kind='strip')

# %% [markdown]
# # scatterplot
# num-num
# cat-cat
# bivariate

# %% [markdown]
# scatter plot used genarally axes plot
# for convert into figure level use relplot

# %%
sns.scatterplot(data['size'],data['price'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='size', ylabel='price'>

# %%
sns.relplot(data['size'],data['price'],kind='scatter')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # lineplot similar as scatter plot but data or continue line represent use lineplot

# %%
sns.lineplot(data['size'],data['price'],data=data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='size', ylabel='price'>

# %% [markdown]
# hue is use for   or make the plot

# %% [markdown]
# facet plot

# %% [markdown]
# #

# %%
data5 =pd.read_csv('batsman_season_record.csv')
data5
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
data6 =pd.read_csv('fours-sixes.csv')
data6
# Out:
#    season  Fours  Sixes
# 0    2013   2054    681
# 1    2012   1911    733
# 2    2016   1633    639
# 3    2017   1612    706
# 4    2015   1611    692
# 5    2014   1563    715

# %%
data7 =pd.read_csv('sharma-kohli.csv')
data7
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
sns.relplot(x='Fours',kind='scatter',col='season',data=data6)

# %%
sns.relplot(data6['Fours'], data6['Sixes'],kind='scatter',col='season',data=data6,col_wrap=2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot(data6['Fours'], data6['Sixes'],kind='line',col='season',data=data6,col_wrap=2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # * distribution plot- used univariate ,range,cental tendency(data divide),outlier
# 1. hisplot-univariate(axis level-histplot,kdeplot,rugplot)(figure-displot)
# 2. kdeplot-
# 3.rugplot-

# %%
sns.histplot(data6['Fours'])
# Out:
# <AxesSubplot:xlabel='Fours', ylabel='Count'>

# %%
sns.histplot(data['availability'])
# Out:
# <AxesSubplot:xlabel='availability', ylabel='Count'>

# %%
sns.displot(data5['2015'],kind='hist',bins=20)

# %%
sns.displot(data5['2015'],kind='kde')

# %% [markdown]
# # kdeplot-kernal density estimation(produce contionous density ,not work like hist first bins create work

# %%
sns.displot(data5['2015'],kind='kde',fill=True)

# %%
sns.kdeplot(data5['2015'],fill=True)
# Out:
# <AxesSubplot:xlabel='2015', ylabel='Density'>

# %% [markdown]
# # rugplot(marginal distributions)(support just)

# %%
sns.histplot(data6['Fours'])
sns.rugplot(data6['Fours'])
#plt.show()
# Out:
# <AxesSubplot:xlabel='Fours', ylabel='Count'>

# %%
sns.kdeplot(data6['Fours'])
sns.rugplot(data6['Fours'])
# Out:
# <AxesSubplot:xlabel='Fours', ylabel='Density'>

# %% [markdown]
# # bivariate(hist.kde,rug)

# %%
sns.histplot(data=data, x='bath', y='price')
# Out:
# <AxesSubplot:xlabel='bath', ylabel='price'>

# %%
sns.kdeplot(data=data, x='bath', y='price')
# Out:
# <AxesSubplot:xlabel='bath', ylabel='price'>

# %% [markdown]
# # matrix-
# 1.heatmap-axis level
# 2.clustermap-cmap(simailar col-join

# %%
x=data7.pivot(index='RG Sharma',columns='index',values='V Kohli')

# %%
sns.heatmap(x,fmt='d',cbar=False)
# Out:
# <AxesSubplot:xlabel='index', ylabel='RG Sharma'>

# %%
sns.heatmap(data7)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data6,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(data6,annot=True)

# %% [markdown]
# # cluster map

# %% [markdown]
# # sns.load_dataset('name')

# %% [markdown]
# # categorical plot

# %% [markdown]
# # box plot-outlier(
