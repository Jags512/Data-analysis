# %% [markdown]
# # cate distribution / figure level-catplot
# 1.boxplot(split not work)------------(num-num)/num-cat)
# 2.violinplot(combination-box plus kdeplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import  seaborn as sns
import plotly.express as px

# %%
data =pd.read_csv('Pune_House_Data.csv')
data
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price         site_location
# ...

# %%
df=pd.read_csv('sharma-kohli.csv')
df
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
data4 =pd.read_csv('test.csv')
data4.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 44    1505          20       FV         80.0     8000   Pave   NaN      Reg
# 1242  2703          90       RM         68.0     8927   Pave   NaN      Reg
# 1116  2577          70       RM         50.0     9060   Pave   NaN      Reg
# 14    1475         120       RL         24.0     2280   Pave   NaN      Reg
# 598   2059          20       RL         74.0     8856   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 44           Lvl    AllPub  ...           0        0    NaN    NaN
# 1242         Lvl    AllPub  ...           0        0    NaN    NaN
# 1116         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 14           Lvl    AllPub  ...           0        0    NaN    NaN
# 598          Lvl    AllPub  ...          95        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
sns.boxplot(x ='area_type',y='price',data =data)
# Out:
# <AxesSubplot:xlabel='area_type', ylabel='price'>

# %%
sns.boxplot(x ='bath',y='price',data =data)
# Out:
# <AxesSubplot:xlabel='bath', ylabel='price'>

# %%
sns.boxplot(x ='SaleCondition',y='LotArea',data =data4)
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='LotArea'>

# %%
sns.violinplot(x ='SaleCondition',y='LotArea',data =data4,split=True)
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='LotArea'>

# %%
sns.violinplot(x ='SaleCondition',y='LotArea',data =data4)
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='LotArea'>

# %%
sns.violinplot(x ='bath',y='price',data =data)
# Out:
# <AxesSubplot:xlabel='bath', ylabel='price'>

# %%
sns.violinplot(x ='index',y='RG Sharma',data =df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='RG Sharma'>

# %% [markdown]
# # single boxplot-only numerial

# %%
sns.boxplot(data=df,y='V Kohli')
# Out:
# <AxesSubplot:ylabel='V Kohli'>

# %%
sns.violinplot(data=df,y='V Kohli')
# Out:
# <AxesSubplot:ylabel='V Kohli'>

# %%
sns.catplot(x ='SaleCondition',y='LotArea',data =data4,kind='box')

# %%
sns.catplot(x ='SaleCondition',y='LotArea',data =data4,kind='box',col='MSZoning',col_wrap=2)

# %%
sns.catplot(x ='SaleCondition',y='LotArea',data =data4,kind='violin')
