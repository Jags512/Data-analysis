# %% [markdown]
# # linear regression plot(num-num)
# 1.regplot(num-num)  -------- not work hue par
# 2. reside   future best
# ----------lmplot figure level

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import  seaborn as sns
import plotly.express as px

# %%
data =pd.read_csv('Pune_House_Data.csv')
data
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price         site_location
# ...

# %%
df=pd.read_csv('sharma-kohli.csv')
df
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
data4 =pd.read_csv('test.csv')
data4.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 608   2069          20       RL         60.0    10122   Pave   NaN      Reg
# 542   2003          60       RL         73.0     9801   Pave   NaN      Reg
# 624   2085          20       RL         69.0     7590   Pave   NaN      Reg
# 1429  2890          30       RM         50.0     7030   Pave   NaN      Reg
# 1207  2668          60       RL         65.0    10237   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 608          Lvl    AllPub  ...           0        0    NaN  GdPrv
# 542          Lvl    AllPub  ...           0        0    NaN    NaN
# 624          Lvl    AllPub  ...           0        0    NaN    NaN
# 1429         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1207         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
sns.regplot(x ='price',y='bath',data =data)
# Out:
# <AxesSubplot:xlabel='price', ylabel='bath'>

# %%
sns.lmplot(x ='price',y='bath',data =data)

# %%
sns.residplot(x ='price',y='bath',data =data)
# Out:
# <AxesSubplot:xlabel='price', ylabel='bath'>

# %% [markdown]
# # facetgrid---------- relplot-cat-dist-implot

# %%
sns.catplot(x ='SaleCondition',y='LotArea',data =data4,kind='violin',col='MSZoning',col_wrap=2)

# %%
a =sns.FacetGrid(data =data4,col='MSZoning')

# %%
a =sns.FacetGrid(data =data4,col='MSZoning')
a.map(sns.violinplot,'SaleCondition','LotArea')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
a =sns.FacetGrid(data =data4,col='MSZoning')
a.map(sns.boxplot,'SaleCondition','LotArea')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# # pairgrid ----vs ------------pairplot

# %%
sns.pairplot(df)

# %%
sns.pairplot(data4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 sns.pairplot(data4)
#
# NameError: name 'sns' is not defined

# %%
sns.pairgrid(data4)
